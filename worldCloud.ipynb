# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('word cloud.csv')
df.head()
# Out:
#                 words  number
# 0   automated vehicle      10
# 1   automated driving      10
# 2  autonomous vehicle      10
# 3  autonomous driving      10
# 4        self-driving       8

# %%
new_df = df.loc[df.index.repeat(df.number)]
words = new_df.words
text = " ".join(t.replace(' ', '-') for t in words)
text
# Out:
# 'automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-vehicle automated-driving automated-driving automated-driving automated-driving automated-driving automated-driving automated-driving automated-driving automated-driving automated-driving autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-vehicle autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving autonomous-driving self-driving self-driving self-driving self-driving self-driving self-driving self-driving self-driving driverless- driverless- driverless- driverless- driverless- driverless- driverless- vehicle-automation vehicle-automation vehicle-automation vehicle-auto
# ...

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(width = 1000, height = 1000, background_color="white", 
                        contour_color='firebrick', stopwords = stopwords, 
                        min_font_size = 12).generate(text)
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.show() 
wordcloud.to_file('wordcloud.eps')

# %%
# Generate word cloud from frequencies
d = dict(zip(df.words, df.number))
wordcloud = WordCloud(width = 1000, height = 800, background_color="white", 
                        contour_color='firebrick', stopwords = stopwords, 
                        min_font_size = 12).generate_from_frequencies(d)
plt.figure(figsize = (12, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show() 
wordcloud.to_file('wordcloud.eps')
